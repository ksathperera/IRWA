# %%
teams = ["India", "England", "NZ", "Aus"]
captains = ["Kohli","Root","Williaamson", "Smith"]

# %%
tuple(teams)
# Out:
# ('India', 'England', 'NZ', 'Aus')

# %%
tuple(captains)
# Out:
# ('Kohli', 'Root', 'Williaamson', 'Smith')

# %%
con = zip(teams,captains)

# %%
print(con)
# Out:
# <zip object at 0x7feb79304300>

# %%
tuple(zip(teams,captains))   #to concatenate these two lists
# Out:
# (('India', 'Kohli'),
#  ('England', 'Root'),
#  ('NZ', 'Williaamson'),
#  ('Aus', 'Smith'))

# %%
#madam's answer
teams = ["India", "England", "NZ", "Aus"]
captains = ["Kohli","Root","Williaamson", "Smith"]
list3 = [i + j for i,j in zip(teams,captains)]
print(list3)

print(tuple(zip(teams,captains)))
# Out:
# ['IndiaKohli', 'EnglandRoot', 'NZWilliaamson', 'AusSmith']
# (('India', 'Kohli'), ('England', 'Root'), ('NZ', 'Williaamson'), ('Aus', 'Smith'))

# %%
#question 2
